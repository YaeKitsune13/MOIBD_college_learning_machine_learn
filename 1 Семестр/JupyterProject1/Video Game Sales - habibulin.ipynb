# %% [markdown]
# # Video Game Sales

# %% [markdown]
# ### Подключение библиотек

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %% [markdown]
# ### Загрузка данных

# %%
vgs = pd.read_csv(r'../vgsales.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 vgs = pd.read_csv(r'../vgsales.csv')
#
# ...

# %%
vgs.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %% [markdown]
# #### Описание данных

# %% [markdown]
# Этот набор данных содержит список видеоигр, продажи которых превысили 100 000 копий.
#
# Name - Название игры
#
# Platform - Платформа выпуска игр (например, PC, PS4 и т.д.)
#
# Year - Год выпуска игры
#
# Genre - Жанр игры
#
# Publisher - Издатель игры
#
# NA_Sales - Продажи в Северной Америке (в миллионах)
#
# EU_Sales - Продажи в Европе (в миллионах)
#
# JP_Sales - Продажи в Японии (в миллионах)
#
# Other_Sales - Продажи в остальном мире (в миллионах)
#
# Global_Sales - Общий объем продаж по всему миру.

# %% [markdown]
# ##### Выведите размерность и краткую информацию о наборе данных

# %%
vgs.shape
# Out:
# (16598, 11)

# %%
# Out:
# (16598, 11)

# %%
vgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ##### Выведите краткую статистическую информацию по набору данных

# %%
vgs.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
vgs.describe(include=[object])
# Out:
#                                Name Platform   Genre        Publisher
# count                         16598    16598   16598            16540
# unique                        11493       31      12              578
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2163    3316             1351

# %%
# Out:
#                                Name Platform   Genre        Publisher
# count                         16598    16598   16598            16540
# unique                        11493       31      12              578
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2163    3316             1351

# %% [markdown]
# ##### Проверьте набор данных на наличие пропущенных и дублирующих значений

# %%
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
vgs.duplicated().sum()
# Out:
# 0

# %%
# Out:
# 0

# %% [markdown]
# #### Напишите краткий вывод о наборе данных

# %% [markdown]
# ### Заполнение пустых записей

# %% [markdown]
# Удалите пропущенные значения по признаку Publisher, а по признаку Year - замените на среднее значение. Значения по полю Year преобразуйте в целый тип. Удалите признак Rank. После преобразований, убедитесь, что изменения сохранились в наборе данных.

# %%
vgs['Publisher'].isna().value_counts()
# Out:
# Publisher
# False    16540
# True        58
# Name: count, dtype: int64

# %%
vgs['Year'] = vgs['Year'].apply(lambda x : int(x))

# %%
vgs = vgs.dropna()

# %%
vgs['Publisher'].isna().value_counts()
# Out:
# Publisher
# False    16291
# Name: count, dtype: int64

# %%
vgs = vgs.drop(columns=['Rank'])

# %%
vgs.head()
# Out:
#                        Name Platform    Year         Genre Publisher  \
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
vgs.head()
# Out:
#                        Name Platform  Year         Genre Publisher  NA_Sales  \
# 0                Wii Sports      Wii  2006        Sports  Nintendo     41.49
# 1         Super Mario Bros.      NES  1985      Platform  Nintendo     29.08
# 2            Mario Kart Wii      Wii  2008        Racing  Nintendo     15.85
# 3         Wii Sports Resort      Wii  2009        Sports  Nintendo     15.75
# 4  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 4      8.89     10.22         1.00         31.37

# %%
# Out:
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
vgs.shape
# Out:
# (16598, 10)

# %%
vgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16291 non-null  object
#  1   Platform      16291 non-null  object
#  2   Year          16291 non-null  float64
#  3   Genre         16291 non-null  object
#  4   Publisher     16291 non-null  object
#  5   NA_Sales      16291 non-null  float64
#  6   EU_Sales      16291 non-null  float64
#  7   JP_Sales      16291 non-null  float64
#  8   Other_Sales   16291 non-null  float64
#  9   Global_Sales  16291 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.9+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16540 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16540 non-null  object
#  1   Platform      16540 non-null  object
#  2   Year          16540 non-null  int32
#  3   Genre         16540 non-null  object
#  4   Publisher     16540 non-null  object
#  5   NA_Sales      16540 non-null  float64
#  6   EU_Sales      16540 non-null  float64
#  7   JP_Sales      16540 non-null  float64
#  8   Other_Sales   16540 non-null  float64
#  9   Global_Sales  16540 non-null  float64
# dtypes: float64(5), int32(1), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Анализ продаж видеоигр

# %% [markdown]
# #### 1. В каком году было выпущено больше всего игр? Выведите первые 10 записей.

# %%
vgs['Year'].value_counts().sort_values(ascending=False).head(10)
# Out:
# Year
# 2009    1431
# 2008    1428
# 2010    1257
# 2007    1201
# 2011    1136
# 2006    1008
# 2005     936
# 2002     829
# 2003     775
# 2004     744
# Name: count, dtype: int64

# %%
# Out:
# Year
# 2007    1450
# 2009    1431
# 2008    1428
# 2010    1257
# 2011    1136
# 2006    1008
# 2005     936
# 2002     829
# 2003     775
# 2004     744
# Name: count, dtype: int64

# %%
vgs_years = pd.DataFrame(vgs['Year'].value_counts().sort_values(ascending=False).head(10).reset_index())
vgs_years
# Out:
#      Year  count
# 0  2009.0   1431
# 1  2008.0   1428
# 2  2010.0   1257
# 3  2007.0   1201
# 4  2011.0   1136
# 5  2006.0   1008
# 6  2005.0    936
# 7  2002.0    829
# 8  2003.0    775
# 9  2004.0    744

# %%
sb.barplot(data=vgs_years,x='Year',y='count')
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
print(f"Количество уникальных значений в Platform: {len(vgs['Platform'].unique())}")
print(f"Количество уникальных значений в Genre: {len(vgs['Genre'].unique())}")
print(f"Количество уникальных значений в Publisher {len(vgs['Publisher'].unique())}")
# Out:
# Количество уникальных значений в Platform: 31
# Количество уникальных значений в Genre: 12
# Количество уникальных значений в Publisher 576

# %%
vgs_points = pd.DataFrame(vgs[['Year','Global_Sales']].value_counts())
vgs_points
# Out:
#                      count
# Year   Global_Sales
# 2010.0 0.02            114
# 2006.0 0.02            109
# 2007.0 0.02             98
# 2008.0 0.02             95
# 2009.0 0.02             84
# ...                    ...
# 1981.0 0.40              1
#        0.43              1
# 2003.0 3.90              1
# 1981.0 0.48              1
#        0.50              1
#
# [3772 rows x 1 columns]

# %%
plt.figure(figsize=(20,10))
sb.scatterplot(data=vgs_points,x='Year',y='Global_Sales',s=200)
# Out:
# <Axes: xlabel='Year', ylabel='Global_Sales'>

# %%
# Scatterplot

# %% [markdown]
# #### 2. Получите среднюю стоимость продаж в Европе

# %%
vgs['EU_Sales'].mean()
# Out:
# np.float64(0.14773126266036463)

# %%
# Out:
# 0.1468833131801693

# %% [markdown]
# #### 3. Получите максимальную стоимость продаж в Японии и вывведите полную информацию об игре с максимальной суммой продаж

# %%
vgs['JP_Sales'].max()
# Out:
# 10.22

# %%
# Out:
# 10.22

# %%
pd.DataFrame(vgs.iloc[vgs['JP_Sales'].idxmax()]).T
# Out:
#                        Name Platform    Year         Genre Publisher NA_Sales  \
# 4  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo    11.27
#
#   EU_Sales JP_Sales Other_Sales Global_Sales
# 4     8.89    10.22         1.0        31.37

# %%
# Out:
#                        Name Platform  Year         Genre Publisher  NA_Sales  \
# 4  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 4      8.89     10.22          1.0         31.37

# %% [markdown]
# ##### Выведите первые 10 записей с максимальными суммами продажам в Японии по годам

# %%
yearly_jp_sales = vgs.groupby('Year')['JP_Sales'].sum().reset_index()
top_10_years = yearly_jp_sales.sort_values('JP_Sales', ascending=False).head(10).reset_index().drop(columns='index')
top_10_years
# Out:
#      Year  JP_Sales
# 0  2006.0     73.73
# 1  2009.0     61.89
# 2  2007.0     60.29
# 3  2008.0     60.26
# 4  2010.0     59.49
# 5  1996.0     57.44
# 6  2005.0     54.28
# 7  2011.0     53.04
# 8  1999.0     52.34
# 9  2012.0     51.74

# %%
# Out:
#    Year  JP_Sales
# 0  2006     73.73
# 1  2007     66.11
# 2  2009     61.89
# 3  2008     60.26
# 4  2010     59.49
# 5  1996     57.44
# 6  2005     54.28
# 7  2011     53.04
# 8  1999     52.34
# 9  2012     51.74

# %%
plt.figure(figsize=(10,10))
sb.barplot(data=top_10_years,x='Year',y='JP_Sales', palette='Set2', hue='Year')
# Out:
# <Axes: xlabel='Year', ylabel='JP_Sales'>

# %% [markdown]
# #### 4. К какому жанру относится видеоигра "Brain Age 2: More Training in Minutes a Day" video game?

# %%
vgs[vgs['Name'] == "Brain Age 2: More Training in Minutes a Day"]['Genre']
# Out:
# 27    Puzzle
# Name: Genre, dtype: object

# %%
# Out:
# 27    Puzzle
# Name: Genre, dtype: object

# %%
vgs
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# 2#### 5.  Каков объём продаж видеоигры «Grand Theft Auto: Vice City» по всему миру?

# %%
i = vgs[vgs['Name'] == "Grand Theft Auto: Vice City"]['Global_Sales']
i
# Out:
# 24       16.15
# 13732     0.04
# Name: Global_Sales, dtype: float64

# %%
# Out:
# 24       16.15
# 13732     0.04
# Name: Global_Sales, dtype: float64

# %%
# Out:
#                               Name Platform  Year   Genre  \
# 24     Grand Theft Auto: Vice City      PS2  2002  Action
# 13732  Grand Theft Auto: Vice City       PC  2003  Action
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 24     Take-Two Interactive      8.41      5.49      0.47         1.78
# 13732  Take-Two Interactive      0.00      0.03      0.00         0.01
#
#        Global_Sales
# 24            16.15
# 13732          0.04

# %% [markdown]
# #### 6. Выведите название видеоигры, которая имеет самые высокие продажи в Северной Америке.

# %%
# Out:
# 0    Wii Sports
# Name: Name, dtype: object

# %% [markdown]
# #### 7. Выведите видеоигры с самыми низкими продажами в мире

# %%
# Out:
#                                                     Name  Global_Sales
# 15980                                              Turok          0.01
# 15981                     Coven and Labyrinth of Refrain          0.01
# 15982  Super Battle For Money Sentouchuu: Kyuukyoku n...          0.01
# 15983                                   Dragon Zakura DS          0.01
# 15984                             Chameleon: To Dye For!          0.01
# ...                                                  ...           ...
# 16593                 Woody Woodpecker in Crazy Castle 5          0.01
# 16594                      Men in Black II: Alien Escape          0.01
# 16595   SCORE International Baja 1000: The Official Game          0.01
# 16596                                         Know How 2          0.01
# 16597                                   Spirits & Spells          0.01
#
# [610 rows x 2 columns]

# %% [markdown]
# #### 8. Игр какого жанра было создано больше всего?

# %%
vgs['Genre'].value_counts().count()
# Out:
# np.int64(12)

# %%
# Out:
# 12

# %%
vgs['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
vgs['Genre'].value_counts()
# Out:
# Genre
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: count, dtype: int64

# %%
# Out:
# Genre
# Action          3309
# Sports          2343
# Misc            1712
# Role-Playing    1486
# Shooter         1308
# Adventure       1282
# Racing          1248
# Platform         884
# Simulation       863
# Fighting         846
# Strategy         678
# Puzzle           581
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
df = pd.DataFrame(vgs['Genre'].value_counts())
sb.barplot(data=df,x='Genre', y='count',palette='Set2', hue='Genre')
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %% [markdown]
# #### 9. Лучшие игры за 5 лет выпуска по жанрам

# %%
recent_years = vgs['Year'].unique()[:5]
recent_games = vgs[vgs['Year'].isin(recent_years)]
genre_year_counts = recent_games.groupby(['Year', 'Genre']).size().reset_index(name='Count')
plt.figure(figsize=(15,10))
sb.barplot(data=genre_year_counts,x='Year',y='Count', hue='Genre')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %% [markdown]
# #### 10.  В каком году были самые высокие продажи по всему миру?¶

# %%
data_year = pd.DataFrame(vgs.groupby('Year')['Global_Sales'].sum().sort_values(ascending=False))
data_year
# Out:
#         Global_Sales
# Year
# 2008.0        678.90
# 2009.0        667.30
# 2007.0        609.92
# 2010.0        600.29
# 2006.0        521.04
# 2011.0        515.80
# 2005.0        458.51
# 2004.0        414.01
# 2002.0        395.52
# 2013.0        368.11
# 2012.0        363.49
# 2003.0        357.85
# 2014.0        337.03
# 2001.0        331.47
# 2015.0        264.44
# 1998.0        256.47
# 1999.0        251.27
# 2000.0        201.56
# 1997.0        200.98
# 1996.0        199.15
# 1995.0         88.11
# 1994.0         79.17
# 1992.0         76.16
# 1989.0         73.45
# 2016.0         70.90
# 1985.0         53.94
# 1984.0         50.36
# 1990.0         49.39
# 1988.0         47.22
# 1993.0         45.98
# 1986.0         37.07
# 1981.0         35.77
# 1991.0         32.23
# 1982.0         28.86
# 1987.0         21.74
# 1983.0         16.79
# 1980.0         11.38
# 2020.0          0.29
# 2017.0          0.05

# %%
data_year.head(10)
# Out:
#         Global_Sales
# Year
# 2008.0        678.90
# 2009.0        667.30
# 2007.0        609.92
# 2010.0        600.29
# 2006.0        521.04
# 2011.0        515.80
# 2005.0        458.51
# 2004.0        414.01
# 2002.0        395.52
# 2013.0        368.11

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sb.barplot(data=data_year,x='Year',y='Global_Sales')
# Out:
# <Axes: xlabel='Year', ylabel='Global_Sales'>

# %% [markdown]
# #### 11. Игры какого жанра имеют самую высокую цену продажи в мире

# %%
plt.figure(figsize=(15,10))
genre_sales = pd.DataFrame(vgs.groupby('Genre')['Global_Sales'].sum().sort_values(ascending=False))
sb.barplot(data=genre_sales,x='Genre',y='Global_Sales')
# Out:
# <Axes: xlabel='Genre', ylabel='Global_Sales'>

# %% [markdown]
# #### 12. На какой платформе самая высокая цена продажи в мире?

# %%
plt.figure(figsize=(15,10))
data_year = pd.DataFrame(vgs.groupby('Platform')['Global_Sales'].sum().sort_values(ascending=False))
sb.barplot(data=data_year,x='Platform',y='Global_Sales')
# Out:
# <Axes: xlabel='Platform', ylabel='Global_Sales'>

# %% [markdown]
# #### 13. Выведите топ 20 Publisher

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
data_year = pd.DataFrame(vgs.groupby('Publisher')['Global_Sales'].sum().sort_values(ascending=False))[:20]
sb.barplot(data=data_year,x='Publisher',y='Global_Sales')
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %% [markdown]
# #### 14. Общий доход по регионам

# %%
vgs
# Out:
#                                                    Name Platform  Year  \
# 0                                            Wii Sports      Wii  2006
# 1                                     Super Mario Bros.      NES  1985
# 2                                        Mario Kart Wii      Wii  2008
# 3                                     Wii Sports Resort      Wii  2009
# 4                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594                     Men in Black II: Alien Escape       GC  2003
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596                                        Know How 2       DS  2010
# 16597                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
reg = pd.DataFrame(vgs[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']].sum()).reset_index()
reg.columns = ['Region', 'Sales']

# %%
# Out:
#         region     sale
# 0     NA_Sales  4384.41
# 1     EU_Sales  2429.45
# 2     JP_Sales  1290.09
# 3  Other_Sales   797.08

# %%
plt.pie(data=reg,x = reg['Sales'],labels=reg['Region'],autopct='%1.1f%%')
plt.show()

# %%
sb.barplot(data=reg,x='Region',y='Sales')
# Out:
# <Axes: xlabel='Region', ylabel='Sales'>

# %%
# Out:
# <Axes: xlabel='region', ylabel='sale'>

# %%
# Out:
# <Axes: >

# %% [markdown]
# ### 15.Pair plot

# %%
df = vgs[['Year','Platform','Genre','NA_Sales',"EU_Sales","Other_Sales"]]
df
# Out:
#          Year Platform         Genre  NA_Sales  EU_Sales  Other_Sales
# 0      2006.0      Wii        Sports     41.49     29.02         8.46
# 1      1985.0      NES      Platform     29.08      3.58         0.77
# 2      2008.0      Wii        Racing     15.85     12.88         3.31
# 3      2009.0      Wii        Sports     15.75     11.01         2.96
# 4      1996.0       GB  Role-Playing     11.27      8.89         1.00
# ...       ...      ...           ...       ...       ...          ...
# 16593  2002.0      GBA      Platform      0.01      0.00         0.00
# 16594  2003.0       GC       Shooter      0.01      0.00         0.00
# 16595  2008.0      PS2        Racing      0.00      0.00         0.00
# 16596  2010.0       DS        Puzzle      0.00      0.01         0.00
# 16597  2003.0      GBA      Platform      0.01      0.00         0.00
#
# [16291 rows x 6 columns]

# %%
# Out:
#        Year Platform         Genre  NA_Sales  EU_Sales  Other_Sales
# 0      2006      Wii        Sports     41.49     29.02         8.46
# 1      1985      NES      Platform     29.08      3.58         0.77
# 2      2008      Wii        Racing     15.85     12.88         3.31
# 3      2009      Wii        Sports     15.75     11.01         2.96
# 4      1996       GB  Role-Playing     11.27      8.89         1.00
# ...     ...      ...           ...       ...       ...          ...
# 16593  2002      GBA      Platform      0.01      0.00         0.00
# 16594  2003       GC       Shooter      0.01      0.00         0.00
# 16595  2008      PS2        Racing      0.00      0.00         0.00
# 16596  2010       DS        Puzzle      0.00      0.01         0.00
# 16597  2003      GBA      Platform      0.01      0.00         0.00
#
# [16540 rows x 6 columns]

# %%
sb.pairplot(data=df,palette='Set2',hue='Genre')

# %% [markdown]
# #### 16. Выведите 3 самых распространенных жанра видеоигр в мире

# %%
data_year = vgs['Genre'].value_counts().sort_values(ascending=False)
data_year.head(3)
# Out:
# Genre
# Action    3251
# Sports    2304
# Misc      1686
# Name: count, dtype: int64

# %%
# Out:
# Genre
# Action    3309
# Sports    2343
# Misc      1712
# Name: count, dtype: int64

# %% [markdown]
# ### 17. В названиях скольких видеоигр есть слово «super» ??

# %%
result = vgs[vgs['Name'].str.contains('super',case=False)]
pd.DataFrame(data_year).value_counts()
# Out:
# Name
# False    15913
# True       378
# Name: count, dtype: int64

# %%
# Out:
# 287

# %%
result = pd.DataFrame(data_year).value_counts().reset_index()
plt.pie(data=result,x='count',autopct='%1.1f%%')
plt.title("Процент названий имеющих super в строке")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
